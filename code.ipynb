# %%
import pandas as pd

# %%
CH_cities = pd.read_csv('cities_CH.csv',sep=';')

# %%
cheese_fact_village = {'Name':['Fromagerie villageoise Alosen','Fromagerie villageoise Alterswil','Fromagerie villageoise Arconciel'],
                       'NPA':[6315,1715,1732],
                       'City':['Alosen','Alterswil','Arconciel',],
                       'No':[4245,3345,4127],
                       'Address':['Birchliweg 3','Hauptstrasse 74','Au Village 50',],}

# %%
CH_cities[CH_cities['PLZ']==6315]
# Out:
#      Ortschaftsname   PLZ  Zusatzziffer Gemeindename  BFS-Nr Kantonskürzel  \
# 1684      Morgarten  6315             3       Sattel    1371            SZ
# 1814         Alosen  6315             2    Menzingen    1704            ZG
# 1820      Oberägeri  6315             0    Oberägeri    1706            ZG
# 1821         Alosen  6315             2    Oberägeri    1706            ZG
# 1822      Morgarten  6315             3    Oberägeri    1706            ZG
# 1834      Oberägeri  6315             0   Unterägeri    1709            ZG
#
#                 E            N Sprache    Validity
# 1684  2691974.413  1217222.942      de  2008-07-01
# 1814  2692055.904  1223315.708      de  2008-07-01
# 1820  2688984.926  1221406.559      de  2008-07-01
# 1821  2692030.568  1222178.452      de  2008-07-01
# 1822  2691921.160  1218342.015      de  2008-07-01
# 1834  2687476.300  1222477.322      de  2008-07-01

# %%
cheese_fact_village_df = pd.read_csv('data/cheese_factories.csv',sep=';')
cheese_fact_village_df
# Out:
#      Numero                                               Nom   NPA  \
# 0    4245.0                     Fromagerie villageoise Alosen  6315
# 1    3345.0                  Fromagerie villageoise Alterswil  1715
# 2    4127.0                  Fromagerie villageoise Arconciel  1732
# 3    4128.0                    Fromagerie villageoise Autigny  1742
# 4    4379.0                 Fromagerie villageoise Ballaigues  1338
# ..      ...                                               ...   ...
# 144  4076.0       Fromagerie villageoise Vuarmarens & Environ  1674
# 145  4356.0                   Fromagerie villageoise Vuarrens  1418
# 146  4102.0  Fromagerie villageoise Vuisternens-devant-Romont  1687
# 147  4151.0        Fromagerie villageoise Vuisternens-en-Ogoz  1696
# 148  3321.0                 Fromagerie villageoise Wengliswil  1715
#
#                          Ville                Adresse  \
# 0                       Alosen           Birchliweg 3
# ...

# %%
cheese_fact_village_df = pd.merge(cheese_fact_village_df,CH_cities[['PLZ','Kantonskürzel']],left_on='NPA',right_on='PLZ',how='left')
cheese_fact_village_df
# Out:
#      Numero                                               Nom   NPA  \
# 0    4245.0                     Fromagerie villageoise Alosen  6315
# 1    4245.0                     Fromagerie villageoise Alosen  6315
# 2    4245.0                     Fromagerie villageoise Alosen  6315
# 3    4245.0                     Fromagerie villageoise Alosen  6315
# 4    4245.0                     Fromagerie villageoise Alosen  6315
# ..      ...                                               ...   ...
# 393  4102.0  Fromagerie villageoise Vuisternens-devant-Romont  1687
# 394  4102.0  Fromagerie villageoise Vuisternens-devant-Romont  1687
# 395  4151.0        Fromagerie villageoise Vuisternens-en-Ogoz  1696
# 396  3321.0                 Fromagerie villageoise Wengliswil  1715
# 397  3321.0                 Fromagerie villageoise Wengliswil  1715
#
#                          Ville             Adresse  \
# 0                       Alosen        Birchliweg 3
# ...

# %%
cheese_fact_village_df.to_csv('data/cheese_factories.csv', index=False, encoding='utf-8')
